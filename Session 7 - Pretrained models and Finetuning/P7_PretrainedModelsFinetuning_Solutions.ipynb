# %% [markdown]
# # CNN Transfer Learning

# %% [markdown]
# In this notebook we will learn how to finetune a modern
# CNN architecture from the [`torchvision models`](https://docs.pytorch.org/vision/stable/models.html), which has been pretrained on the [Imagenet dataset](http://www.image-net.org/). The [`torchvision models`](https://docs.pytorch.org/vision/stable/models.html) module implements lots of popular CNN models such as: AlexNet, VGG, ResNet, DenseNet, GoogLeNet, etc.
#
#
# *Credit: This notebook has been adapted from the official [PyTorch finetuning tutorial](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).*
#
# The Imagenet dataset has 1000 classes and millions of images. Training a ResNet-50 model on ImageNet-1k with a single GPU takes several days. The key idea of transfer learning is to reuse the knowledge learned in one task to solve a different task. Transfer learning is especially useful when we do not have lots of training data for the new task nad/or when we want to speed up the training of the new model.
#
# For the target task we will use the [hymenoptera_data dataset](https://download.pytorch.org/tutorial/hymenoptera_data.zip), which consists in only **two classes** ('ants' and 'bees') and only around **one hundred training examples** for each class.

# %% [markdown]
# <table>
#     <tr>
#         <td style="text-align:center">bee</td><td style="text-align:center">ant</td>
#     </tr>
#     <tr>
#         <td><img src="......"></td>
#         <td><img src="......"></td>
#     </tr>
# </table>

# %% [markdown]
# We will perform two types of transfer learning: finetuning and feature extraction. In **finetuning**, we start with a pretrained model and update *all* of the model’s parameters for a new task. In **feature extraction**,
# we start with a pretrained model and only update the final layer weights.
#
# In general both transfer learning methods follow the same few steps:
#
# -  Initialize the pretrained model
# -  Reshape the final layer(s) to have the same number of outputs as the number of classes in the new dataset
# -  Define for the optimization algorithm which parameters we want to update during training
# -  Run the training step

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Load the necessary libraries
#
# The following code imports the packages needed for this example.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms

import matplotlib.pyplot as plt
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  2.10.0+cu128
# Torchvision Version:  0.25.0+cu128

# %%
# If this cell fails you need to change the runtime of your colab notebook to GPU
# Go to Runtime -> Change Runtime Type and select GPU
assert torch.cuda.is_available(), "GPU is not enabled"

# use gpu if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Prepare the dataset
#
# The *hymenoptera_data* dataset is structured such that we can use the [`ImageFolder()`](https://docs.pytorch.org/vision/main/generated/torchvision.datasets.ImageFolder.html) dataset class. Below you can see how to use PyTorch to download a dataset archive, unzip it, and then use the `ImageFolder()` function to create subsets from each subfolder.
#
# Since we will be reusing a pretrained model we must initialize the data transforms as in the original model. See [here](https://pytorch.org/vision/0.8/models.html) for more details.

# %%
# download the dataset
url = 'https://download.pytorch.org/tutorial/hymenoptera_data.zip'
datasets.utils.download_and_extract_archive(url, './data')

data_dir = "./data/hymenoptera_data/"

# ResNet input size
input_size = (224, 224)

# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")


# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

print("Done")
# Out:
# Initializing Datasets and Dataloaders...
# Done
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()

# %% [markdown]
# See how `ImageFolder` creates a subfolder for each class.

# %%
#@title `data_dir` structure
# Adapted from Source - https://stackoverflow.com/a/9728478
# License - CC BY-SA 3.0
import os

def dir_tree(start_path):
    print(f"{os.path.dirname(start_path)}")
    tab = ' ' * 4
    for root, dirs, _ in os.walk(start_path):
        level = root.replace(start_path, '').count(os.sep)
        indent = tab * (level)
        if os.path.basename(root):
          print('{}{}{}/'.format(tab, indent, os.path.basename(root)))
          subindent = tab * (level + 1)

dir_tree(data_dir)
# Out:
# ./data/hymenoptera_data
#     val/
#         ants/
#         bees/
#     train/
#         ants/
#         bees/

# %% [markdown]
# See how the datasets are encapsulated by the `ImageFolder` class.

# %%
#@title `image_datasets`
import pprint
pprint.pp(image_datasets)
# Out:
# {'train': Dataset ImageFolder
#     Number of datapoints: 244
#     Root location: ./data/hymenoptera_data/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            ),
#  'val': Dataset ImageFolder
#     Number of datapoints: 153
#     Root location: ./data/hymenoptera_data/val
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )}

# %% [markdown]
# See our transformations are based on the transformations made on the pretrained `ResNet18` model which we will be using below. For more information [see](https://docs.pytorch.org/vision/stable/models.html#using-the-pre-trained-models).

# %%
#@title `ResNet18` pre-training transforms

from torchvision.models import ResNet18_Weights

# Get transforms in pre-training
weights = ResNet18_Weights.DEFAULT
preprocess = weights.transforms()
preprocess

# You could apply it to the input image
# img_transformed = preprocess(img)
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %% [markdown]
# ### Visualize some images

# %%
import matplotlib.image as mpimg

# show some images
plt.figure(figsize=(16, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    idx = np.random.randint(0,len(image_datasets['train'].samples))
    image = mpimg.imread(image_datasets['train'].samples[idx][0])
    plt.imshow(image)
    plt.axis('off');

# %% [markdown]
# Since we have very little training data it makes sense to use some data augmentation for training.
#
# <span style="color:blue">
#
# **Exercise 1**: Change the transforms in the code below in order to add some data augmentation to the training data. See if you can do a random crop instead of always cropping in the middle, and add horizontal flips. Then recreate the datasets and dataloaders.
#
# </span>

# %%
# CHANGE THE CODE BELOW

# ResNet input size
input_size = (224, 224)

# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),   # ADDED RANDOM RESIZED CROP
        transforms.RandomHorizontalFlip(),          # ADDED RANDOM HORIZONTAL FLIP
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")

# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

print("Done")
# Out:
# Initializing Datasets and Dataloaders...
# Done

# %% [markdown]
# ## Define the training function
#
# The `train_model` function handles the training and validation of a given model. As input, it takes a PyTorch model, a dictionary of dataloaders, a loss function, an optimizer, and a specified number of epochs to train and validate for.
#
# Instead of defining different functions for tranining and validation, we have combined everything into a single one below.
#
# Note that we also have implemented early stopping - we keep track of the performance of our model on the validation set, and we keep a copy of the best model found using Python's `copy.deepcopy()` function. After training finishes, we copy the best weights from the saved model.

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    acc_history = {"train": [], "val": []}
    losses = {"train": [], "val": []}

    # we will keep a copy of the best weights so far according to validation accuracy
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    losses[phase].append(loss.item())

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).cpu().numpy()

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

            acc_history[phase].append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, acc_history, losses

# %% [markdown]
# ## Initialize the ResNet model
#
# We will use the Resnet18 model (the smaller one), as our dataset is small and only has two classes. When we print the model, we see that the last layer is a fully connected layer as shown below:
#
#
#    `(fc): Linear(in_features=512, out_features=1000, bias=True)`

# %%
# This is a function that we will adapt in various ways during the rest of the notebook, right now, it just creates and returns the model and the input size of images
def initialize_model():
    # Resnet18
    model = models.resnet18()

    input_size = 224

    return model, input_size


# Initialize the model
model, input_size = initialize_model()

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 2**: Modify the function `initialize_model` so that it takes the number of classes `num_classes` as an argument, and it reinitializes `model.fc` to be a Linear layer with 512 input features and `num_classes` output features. Then use the function to create a model with 2 output classes.
#
# </span>

# %%
# YOUR CODE HERE

def initialize_model(num_classes):
    # Resnet18
    model = models.resnet18()

    model.fc = nn.Linear(512, num_classes)

    input_size = 224

    return model, input_size


# Number of classes in the dataset
num_classes = 2

# Initialize the model
model, input_size = initialize_model(num_classes)

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# ### Run Training and Validation Step
#
# Let's start by training the model from scratch. What do you think will happen?

# %%
# Send the model to GPU
model = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for
num_epochs = 15

optimizer_ft = optim.Adam(model.parameters(), lr=0.001)

# Train and evaluate
model, hist, losses = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/14
# ----------
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# train Loss: 1.0978 Acc: 0.5451
# val Loss: 3.2229 Acc: 0.5294
#
# Epoch 1/14
# ----------
# train Loss: 0.7401 Acc: 0.5697
# val Loss: 0.7846 Acc: 0.5686
#
# Epoch 2/14
# ----------
# train Loss: 0.7133 Acc: 0.5902
# val Loss: 0.7019 Acc: 0.6209
#
# Epoch 3/14
# ----------
# train Loss: 0.6433 Acc: 0.6598
# val Loss: 0.7593 Acc: 0.5948
#
# Epoch 4/14
# ----------
# train Loss: 0.7061 Acc: 0.5615
# val Loss: 0.6645 Acc: 0.5882
#
# Epoch 5/14
# ----------
# train Loss: 0.6641 Acc: 0.5779
# val Loss: 0.6532 Acc: 0.6405
#
# Epoch 6/14
# ----------
# train Loss: 0.6356 Acc: 0.6189
# val Loss: 0.8416 Acc: 0.6471
#
# Epoch 7/14
# ----------
# train Loss: 0.6777 Acc: 0.6311
# val Loss: 0.7426 Acc: 0.5882
#
# Epoch 8/14
# ----------
# train Loss: 0.6666 Acc: 0.6270
# val Loss: 0.8623 Acc: 0.6078
#
# Epoch 9/14
# ----------
# train Loss: 0.6997 Acc: 0.5738
# val Loss: 0.6669 Acc: 0.6078
#
# Epoch 10/14
# ----------
# train Loss: 0.6073 Acc: 0.7131
# val Loss: 0.6611 Acc: 0.6536
#
# Epoch 11/14
# ----------
# train Loss: 0.6421 Acc: 0.6516
# val Loss: 0.9539 Acc: 0.6144
#
# Epoch 12/14
# ----------
# train Loss: 0.6802 Acc: 0.6189
# val Loss: 0.6597 Acc: 0.6078
#
# Epoch 13/14
# ----------
# train Loss: 0.6379 Acc: 0.6352
# val Loss: 0.6533 Acc: 0.6405
#
# Epoch 14/14
# ----------
# train Loss: 0.6366 Acc: 0.6516
# val Loss: 0.6603 Acc: 0.6144
#
# Training complete in 0m 45s
# Best val Acc: 0.653595

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses["train"], label="training loss")
ax1.plot(losses["val"], label="validation loss")
ax1.set_xlabel("batch")
ax1.legend()

ax2.plot(hist["train"],label="training accuracy")
ax2.plot(hist["val"],label="val accuracy")
ax2.set_xlabel("epoch")
ax2.legend()

plt.show()

# %% [markdown]
# Training from scratch with only 100 examples per class does not allow the network to perform very well in this task. It reaches at most 70% accuracy, and the loss seems not to descrease anymore.

# %% [markdown]
# ## Preparing the model for finetuning and feature extraction
#
# In order to finetune a model or use it for feature extraction, we need to first load the pretrained weights, and then to freeze the part of the model we do not want to change.
#
# In order to load the pretrained weights for the ResNet model we must change a bit more the function `initialize model`. One one hand, we need to load the weights of the pre-trained ResNet model, trained on ImageNet.
#
# Moreover, depending on whether we want to do finetuning (update all parameters of the model) or if we want to do feature extraction (update only the last fully connected layer), we must specify which parameter to update.
#
# The following function sets the `.requires_grad` attribute of all the parameters in the model to False. This way we are freezing the model, since the parameters with `.requires_grad=False` will not be updated during training.

# %%
def freeze_model(model):
    for param in model.parameters():
        param.requires_grad = False

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 3**: Modify the function `initialize_model` so that it takes an extra argument called `finetuning`. If this function is True, then all parameters of the model should be able to update. If it is false, this would mean that we want to do feature extraction, and all parameters of the model should be frozen except the last fully connected layer.
#
# In addition, look up the documentation of [`models.resnet18()`](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html) and initialise the models with the `DEFAULT` weights.
#
# Then create again your model,
#
# </span>

# %%
# YOUR CODE HERE

def initialize_model(num_classes, finetuning = True):
    # Resnet18 with pretrained weights
    model = models.resnet18(weights='DEFAULT') # Notice we are now loading the weights of a ResNet model trained on ImageNet

    # If we want to do Feature Extraction, freeze everything
    if (finetuning == False):
        freeze_model(model)

    # Now change the last FC layer - this by default will have requires_grad on
    model.fc = nn.Linear(512,num_classes)

    input_size = 224

    return model, input_size


# Number of classes in the dataset
num_classes = 2

# Initialize the model
model, input_size = initialize_model(num_classes)

# %% [markdown]
# ### Create the Optimizer
#
# The final step for finetuning and feature extracting is to create an optimizer that **only** updates the desired parameters. Recall that after loading the pretrained model, if `finetuning == False` (we want to do feature extraction instead) we manually set all of the parameters' `.requires_grad` attributes to False. But the parameters of the reinitialized layer that we add afterwards have `.requires_grad=True` by default. So *all parameters that have `.requires_grad=True` should be optimized*. Next, we make a list of such parameters and input this list to the Adam algorithm constructor.

# %%
# Gather the parameters to be optimized/updated in this run. If we are finetuning we will be updating all parameters. However, if we are
# doing feature extract method, we will only update the parameters that we have just initialized, i.e. the parameters with requires_grad is True.

params_to_update = []
for name, param in model.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)


# Now give our optimiser the list of all the parameters that need to be optimized
optimizer_ft = optim.Adam(params_to_update, lr=0.001)

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 4**: Train the model with feature extraction for 15 epochs. This is, you must freeze all parameters except the last fully connected layer. Plot the train/val losses and accuracies.
#
# Do not overwrite the previous best model, losses and accuracies, keep the new ones in separate variables.
#
# </span>

# %%
# YOUR CODE HERE

# Number of classes in the dataset
num_classes = 2

# Initialize the model
model, input_size = initialize_model(num_classes, finetuning = False)

params_to_update = []
for name,param in model.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)


# Now give our optimiser the list of all the parameters that need to be optimized
optimizer_ft = optim.Adam(params_to_update, lr=0.001)

# Send the model to GPU
model = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for
num_epochs = 15

# Train and evaluate
model2, hist2, losses2 = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)

# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses2["train"], label="training loss")
ax1.plot(losses2["val"], label="validation loss")
ax1.set_xlabel("batch")
ax1.legend()

ax2.plot(hist2["train"],label="training accuracy")
ax2.plot(hist2["val"],label="val accuracy")
ax2.set_xlabel("epoch")
ax2.legend()

plt.show()
# Out:
# Epoch 0/14
# ----------
# train Loss: 0.5590 Acc: 0.6885
# val Loss: 0.4187 Acc: 0.8562
#
# Epoch 1/14
# ----------
# train Loss: 0.4659 Acc: 0.7787
# val Loss: 0.3266 Acc: 0.9085
#
# Epoch 2/14
# ----------
# train Loss: 0.3994 Acc: 0.8402
# val Loss: 0.2831 Acc: 0.9216
#
# Epoch 3/14
# ----------
# train Loss: 0.3676 Acc: 0.8279
# val Loss: 0.2514 Acc: 0.9346
#
# Epoch 4/14
# ----------
# train Loss: 0.2844 Acc: 0.8893
# val Loss: 0.2384 Acc: 0.9281
#
# Epoch 5/14
# ----------
# train Loss: 0.3166 Acc: 0.8607
# val Loss: 0.2319 Acc: 0.9412
#
# Epoch 6/14
# ----------
# train Loss: 0.3000 Acc: 0.8770
# val Loss: 0.2349 Acc: 0.9216
#
# Epoch 7/14
# ----------
# train Loss: 0.3316 Acc: 0.8525
# val Loss: 0.2137 Acc: 0.9412
#
# Epoch 8/14
# ----------
# train Loss: 0.2970 Acc: 0.8730
# val Loss: 0.2212 Acc: 0.9412
#
# Epoch 9/14
# ----------
# train Loss: 0.2033 Acc: 0.9385
# val Loss: 0.2330 Acc: 0.9216
#
# Epoch 10/14
# ----------
# train Loss: 0.2517 Acc: 0.8934
# val Loss: 0.2061 Acc: 0.9477
#
# Epoch 11/14
# ----------
# train Loss: 0.2173 Acc: 0.9221
# val Loss: 0.2106 Acc: 0.9412
#
# Epoch 12/14
# ----------
# train Loss: 0.2740 Acc: 0.8975
# val Loss: 0.2274 Acc: 0.9150
#
# Epoch 13/14
# ----------
# train Loss: 0.2854 Acc: 0.8730
# val Loss: 0.2038 Acc: 0.9412
#
# Epoch 14/14
# ----------
# train Loss: 0.2499 Acc: 0.8934
# val Loss: 0.2319 Acc: 0.9085
#
# Training complete in 0m 44s
# Best val Acc: 0.947712

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 5**: Now train the model finetuning all the parameters for 15 epochs. Plot the train/val losses and accuracies.
#
# Do not overwrite the previous best model, losses and accuracies, keep the new ones in separate variables.
#
# </span>

# %%
# YOUR CODE HERE

# Number of classes in the dataset
num_classes = 2

# Initialize the model
model, input_size = initialize_model(num_classes, finetuning = True)


# Observe that all parameters are being optimized
optimizer_ft = optim.Adam(model.parameters(), lr=0.001)

# Send the model to GPU
model = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for
num_epochs = 15

# Train and evaluate
model3, hist3, losses3 = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)

# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses3["train"], label="training loss")
ax1.plot(losses3["val"], label="validation loss")
ax1.set_xlabel("batch")
ax1.legend()

ax2.plot(hist3["train"],label="training accuracy")
ax2.plot(hist3["val"],label="val accuracy")
ax2.set_xlabel("epoch")
ax2.legend()

plt.show()
# Out:
# Epoch 0/14
# ----------
# train Loss: 1.0110 Acc: 0.6230
# val Loss: 2.2139 Acc: 0.6928
#
# Epoch 1/14
# ----------
# train Loss: 0.6978 Acc: 0.6230
# val Loss: 3.2389 Acc: 0.5686
#
# Epoch 2/14
# ----------
# train Loss: 0.6416 Acc: 0.6639
# val Loss: 1.1422 Acc: 0.6471
#
# Epoch 3/14
# ----------
# train Loss: 0.7034 Acc: 0.6066
# val Loss: 0.5853 Acc: 0.7190
#
# Epoch 4/14
# ----------
# train Loss: 0.7823 Acc: 0.6393
# val Loss: 0.8004 Acc: 0.6863
#
# Epoch 5/14
# ----------
# train Loss: 0.6710 Acc: 0.6025
# val Loss: 0.6154 Acc: 0.6928
#
# Epoch 6/14
# ----------
# train Loss: 0.6775 Acc: 0.6352
# val Loss: 0.7438 Acc: 0.6797
#
# Epoch 7/14
# ----------
# train Loss: 0.6439 Acc: 0.6721
# val Loss: 0.6686 Acc: 0.6275
#
# Epoch 8/14
# ----------
# train Loss: 0.5700 Acc: 0.7049
# val Loss: 0.5706 Acc: 0.7320
#
# Epoch 9/14
# ----------
# train Loss: 0.6407 Acc: 0.6598
# val Loss: 0.7630 Acc: 0.7386
#
# Epoch 10/14
# ----------
# train Loss: 0.5530 Acc: 0.7295
# val Loss: 0.6074 Acc: 0.7190
#
# Epoch 11/14
# ----------
# train Loss: 0.6112 Acc: 0.6762
# val Loss: 0.7844 Acc: 0.5556
#
# Epoch 12/14
# ----------
# train Loss: 0.6118 Acc: 0.6680
# val Loss: 0.7274 Acc: 0.6732
#
# Epoch 13/14
# ----------
# train Loss: 0.6436 Acc: 0.6352
# val Loss: 0.6543 Acc: 0.5556
#
# Epoch 14/14
# ----------
# train Loss: 0.5632 Acc: 0.7049
# val Loss: 1.0266 Acc: 0.6340
#
# Training complete in 0m 45s
# Best val Acc: 0.738562

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 6**: Plot the  train/val losses and accuracies of all three approaches: training from scratch, fine-tuning, and feature extraction. To make easier visualization and comparison, use four `plt.subplots`: one for training loss, one for val loss, one for training accuracy, and one for val accuracy.
#
# Make the plot self-explanatory: use legends and titles for each subplot, and a main title for the whole figure.
#
# </span>

# %%
# plot the losses and accuracies of all models
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 6) )

ax1.plot(losses["train"], label="from scratch")
ax1.plot(losses2["train"], label="feature extraction")
ax1.plot(losses3["train"], label="fine-tuning")
ax1.set_title("training loss")
ax1.set_xlabel("batch")
ax1.legend()

ax2.plot(losses["val"], label="from scratch")
ax2.plot(losses2["val"], label="feature extraction")
ax2.plot(losses3["val"], label="fine-tuning")
ax2.set_title("val loss")
ax2.set_xlabel("batch")
ax2.legend()

ax3.plot(hist["train"],label="from scratch")
ax3.plot(hist2["train"],label="feature extraction")
ax3.plot(hist3["train"],label="fine-tuning")
ax3.set_title("training accuracy")
ax3.set_xlabel("epoch")
ax3.legend()

ax4.plot(hist["val"],label="from scratch")
ax4.plot(hist2["val"],label="feature extraction")
ax4.plot(hist3["val"],label="fine-tuning")
ax4.set_title("val accuracy")
ax4.set_xlabel("epoch")
ax4.legend()

plt.tight_layout()

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 7**: Train the ResNet-18 model for a different dataset (MIT Scenes) using the three training strategies: from scratch (do not load pre-trained weights), fine-tuning, and feature extraction. Train the model **for 40 epochs** - each training process should take approx. 10 minutes on colab.
#
# The URL of the dataset is the following (you also have the file on Campus Virtual):
#
# http://pages.cvc.uab.es/dimos/downloads/MIT_scenes.zip
#
# The dataset contains scene images of **8 classes**: coast, forest, highway, inside_city, mountain, open_country, street, and tallbuilding. The number of training images per class varies between 187 and 295.
#
# Train the three models and plot the  train/val losses and accuracies of all of them. Again, to make easier visualization and comparison, use four `plt.subplots`: one for training loss, one for val loss, one for training accuracy, and one for val accuracy.
#
# </span>

# %%
# YOUR CODE HERE

# download the dataset
url = 'http://pages.cvc.uab.es/dimos/downloads/MIT_scenes.zip'
datasets.utils.download_and_extract_archive(url, './data')

data_dir = "./data/MIT_scenes/"

# ResNet input size
input_size = (224,224)

# Just normalization
data_transforms = {
    'train': transforms.Compose([
#        transforms.Resize(input_size),             # Use these two lines if you do not want to add augmentation
#        transforms.CenterCrop(input_size),
        transforms.RandomResizedCrop(input_size),   # RANDOM RESIZED CROP
        transforms.RandomHorizontalFlip(),          # RANDOM HORIZONTAL FLIP
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")


# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

print("Done")
# Out:
# Initializing Datasets and Dataloaders...
# Done

# %%
# YOUR CODE HERE contd

def initialize_model(num_classes, finetuning = True, usePretrainedWeights = True):
    # Initialise Resnet18 with the weights
    weightsToUse = 'DEFAULT' if usePretrainedWeights else None
    model = models.resnet18(weights = weightsToUse)

    # If we want to do Feature Extraction, freeze everything
    if (finetuning == False):
        freeze_model(model)

    # Now change the last FC layer - this by default will have requires_grad on
    model.fc = nn.Linear(512,num_classes)

    input_size = 224

    return model, input_size


# Number of classes in the dataset
num_classes = 8

# Initialize the model
all_models = [initialize_model(num_classes, usePretrainedWeights = False)[0],                        # From Scratch
              initialize_model(num_classes, finetuning = True,  usePretrainedWeights = True)[0],     # Finetuning
              initialize_model(num_classes, finetuning = False, usePretrainedWeights = True)[0]]     # Feature Extraction
model_labels = ['from scratch', 'fine tunning', 'feature extraction']

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for
num_epochs = 40

all_loss_hist = []
all_acc_hist = []

for model in all_models:

    params_to_update = []
    for name, param in model.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)

    # Observe that all parameters are being optimized
    optimizer_ft = optim.Adam(params_to_update, lr=0.001)

    # Send the model to GPU
    model = model.to(device)

    # Train and evaluate
    best_model, hist, losses = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)

    all_loss_hist.append(losses)
    all_acc_hist.append(hist)
# Out:
# Epoch 0/39
# ----------
# train Loss: 2.0084 Acc: 0.2701
# val Loss: 1.6984 Acc: 0.4040
#
# Epoch 1/39
# ----------
# train Loss: 1.5636 Acc: 0.4296
# val Loss: 1.4013 Acc: 0.4833
#
# Epoch 2/39
# ----------
# train Loss: 1.3685 Acc: 0.5040
# val Loss: 0.9503 Acc: 0.6382
#
# Epoch 3/39
# ----------
# train Loss: 1.2570 Acc: 0.5502
# val Loss: 0.8638 Acc: 0.7026
#
# Epoch 4/39
# ----------
# train Loss: 1.1471 Acc: 0.5880
# val Loss: 0.8631 Acc: 0.6840
#
# Epoch 5/39
# ----------
# train Loss: 1.0924 Acc: 0.6114
# val Loss: 0.8126 Acc: 0.7187
#
# Epoch 6/39
# ----------
# train Loss: 1.0048 Acc: 0.6544
# val Loss: 0.8866 Acc: 0.7038
#
# Epoch 7/39
# ----------
# train Loss: 1.0045 Acc: 0.6406
# val Loss: 0.8159 Acc: 0.7212
#
# Epoch 8/39
# ----------
# train Loss: 0.9741 Acc: 0.6603
# val Loss: 0.7643 Acc: 0.7274
#
# Epoch 9/39
# ----------
# train Loss: 0.8750 Acc: 0.6890
# val Loss: 0.5948 Acc: 0.7906
#
# Epoch 10/39
# ----------
# train Loss: 0.8846 Acc: 0.6863
# val Loss: 0.7285 Acc: 0.7385
#
# Epoch 11/39
# ----------
# train Loss: 0.8365 Acc: 0.7071
# val Loss: 0.5795 Acc: 0.8104
#
# Epoch 12/39
# ----------
# train Loss: 0.8616 Acc: 0.6964
# val Loss: 0.5694 Acc: 0.8116
#
# Epoch 13/39
# ----------
# train Loss: 0.8306 Acc: 0.7044
# val Loss: 0.5692 Acc: 0.8079
#
# Epoch 14/39
# ----------
# train Loss: 0.8057 Acc: 0.7156
# val Loss: 0.6132 Acc: 0.7856
#
# Epoch 15/39
# ----------
# train Loss: 0.7915 Acc: 0.7156
# val Loss: 0.5003 Acc: 0.8278
#
# Epoch 16/39
# ----------
# train Loss: 0.7454 Acc: 0.7326
# val Loss: 0.5462 Acc: 0.8129
#
# Epoch 17/39
# ----------
# train Loss: 0.7279 Acc: 0.7485
# val Loss: 0.5133 Acc: 0.8278
#
# Epoch 18/39
# ----------
# train Loss: 0.7025 Acc: 0.7602
# val Loss: 0.4762 Acc: 0.8451
#
# Epoch 19/39
# ----------
# train Loss: 0.7161 Acc: 0.7549
# val Loss: 0.4954 Acc: 0.8302
#
# Epoch 20/39
# ----------
# train Loss: 0.7213 Acc: 0.7512
# val Loss: 0.4592 Acc: 0.8550
#
# Epoch 21/39
# ----------
# train Loss: 0.6783 Acc: 0.7634
# val Loss: 0.5335 Acc: 0.8203
#
# Epoch 22/39
# ----------
# train Loss: 0.7031 Acc: 0.7432
# val Loss: 0.4509 Acc: 0.8600
#
# Epoch 23/39
# ----------
# train Loss: 0.6201 Acc: 0.7879
# val Loss: 0.3571 Acc: 0.8823
#
# Epoch 24/39
# ----------
# train Loss: 0.6520 Acc: 0.7762
# val Loss: 0.4119 Acc: 0.8724
#
# Epoch 25/39
# ----------
# train Loss: 0.6171 Acc: 0.7826
# val Loss: 0.4236 Acc: 0.8513
#
# Epoch 26/39
# ----------
# train Loss: 0.6063 Acc: 0.7943
# val Loss: 0.3870 Acc: 0.8674
#
# Epoch 27/39
# ----------
# train Loss: 0.6087 Acc: 0.7873
# val Loss: 0.3716 Acc: 0.8835
#
# Epoch 28/39
# ----------
# train Loss: 0.5952 Acc: 0.7815
# val Loss: 0.6040 Acc: 0.7955
#
# Epoch 29/39
# ----------
# train Loss: 0.5799 Acc: 0.7921
# val Loss: 0.4111 Acc: 0.8501
#
# Epoch 30/39
# ----------
# train Loss: 0.5636 Acc: 0.7985
# val Loss: 0.4370 Acc: 0.8476
#
# Epoch 31/39
# ----------
# train Loss: 0.5548 Acc: 0.8129
# val Loss: 0.4335 Acc: 0.8550
#
# Epoch 32/39
# ----------
# train Loss: 0.5806 Acc: 0.7895
# val Loss: 0.3498 Acc: 0.8860
#
# Epoch 33/39
# ----------
# train Loss: 0.5185 Acc: 0.8161
# val Loss: 0.5069 Acc: 0.8364
#
# Epoch 34/39
# ----------
# train Loss: 0.5510 Acc: 0.7980
# val Loss: 0.3969 Acc: 0.8563
#
# Epoch 35/39
# ----------
# train Loss: 0.5070 Acc: 0.8299
# val Loss: 0.4495 Acc: 0.8451
#
# Epoch 36/39
# ----------
# train Loss: 0.5192 Acc: 0.8150
# val Loss: 0.3896 Acc: 0.8686
#
# Epoch 37/39
# ----------
# train Loss: 0.5149 Acc: 0.8214
# val Loss: 0.3764 Acc: 0.8686
#
# Epoch 38/39
# ----------
# train Loss: 0.5030 Acc: 0.8208
# val Loss: 0.3152 Acc: 0.8885
#
# Epoch 39/39
# ----------
# train Loss: 0.4717 Acc: 0.8331
# val Loss: 0.3336 Acc: 0.8872
#
# Training complete in 8m 44s
# Best val Acc: 0.888476
# Epoch 0/39
# ----------
# train Loss: 1.3341 Acc: 0.5417
# val Loss: 0.5913 Acc: 0.8265
#
# Epoch 1/39
# ----------
# train Loss: 1.0895 Acc: 0.6257
# val Loss: 0.6851 Acc: 0.7509
#
# Epoch 2/39
# ----------
# train Loss: 0.9363 Acc: 0.6768
# val Loss: 0.5945 Acc: 0.7955
#
# Epoch 3/39
# ----------
# train Loss: 0.8970 Acc: 0.7044
# val Loss: 0.5626 Acc: 0.8079
#
# Epoch 4/39
# ----------
# train Loss: 0.8744 Acc: 0.7039
# val Loss: 0.6678 Acc: 0.7633
#
# Epoch 5/39
# ----------
# train Loss: 0.8112 Acc: 0.7289
# val Loss: 0.3921 Acc: 0.8761
#
# Epoch 6/39
# ----------
# train Loss: 0.7527 Acc: 0.7517
# val Loss: 0.4812 Acc: 0.8389
#
# Epoch 7/39
# ----------
# train Loss: 0.7683 Acc: 0.7384
# val Loss: 0.3527 Acc: 0.8662
#
# Epoch 8/39
# ----------
# train Loss: 0.7366 Acc: 0.7384
# val Loss: 0.4534 Acc: 0.8463
#
# Epoch 9/39
# ----------
# train Loss: 0.6706 Acc: 0.7772
# val Loss: 0.4110 Acc: 0.8563
#
# Epoch 10/39
# ----------
# train Loss: 0.7083 Acc: 0.7560
# val Loss: 0.2713 Acc: 0.9157
#
# Epoch 11/39
# ----------
# train Loss: 0.6502 Acc: 0.7804
# val Loss: 0.2778 Acc: 0.9083
#
# Epoch 12/39
# ----------
# train Loss: 0.6242 Acc: 0.7863
# val Loss: 0.3163 Acc: 0.8996
#
# Epoch 13/39
# ----------
# train Loss: 0.6613 Acc: 0.7714
# val Loss: 0.3949 Acc: 0.8501
#
# Epoch 14/39
# ----------
# train Loss: 0.6339 Acc: 0.7778
# val Loss: 0.5188 Acc: 0.8228
#
# Epoch 15/39
# ----------
# train Loss: 0.6045 Acc: 0.7879
# val Loss: 0.2661 Acc: 0.9046
#
# Epoch 16/39
# ----------
# train Loss: 0.5802 Acc: 0.7964
# val Loss: 0.2509 Acc: 0.9182
#
# Epoch 17/39
# ----------
# train Loss: 0.5758 Acc: 0.7985
# val Loss: 0.3049 Acc: 0.8860
#
# Epoch 18/39
# ----------
# train Loss: 0.5817 Acc: 0.8017
# val Loss: 0.3787 Acc: 0.8686
#
# Epoch 19/39
# ----------
# train Loss: 0.5728 Acc: 0.7969
# val Loss: 0.4654 Acc: 0.8377
#
# Epoch 20/39
# ----------
# train Loss: 0.5636 Acc: 0.8139
# val Loss: 0.3110 Acc: 0.8959
#
# Epoch 21/39
# ----------
# train Loss: 0.5553 Acc: 0.8028
# val Loss: 0.2804 Acc: 0.9071
#
# Epoch 22/39
# ----------
# train Loss: 0.5800 Acc: 0.8022
# val Loss: 0.3454 Acc: 0.8786
#
# Epoch 23/39
# ----------
# train Loss: 0.4762 Acc: 0.8379
# val Loss: 0.2796 Acc: 0.9071
#
# Epoch 24/39
# ----------
# train Loss: 0.4740 Acc: 0.8389
# val Loss: 0.2826 Acc: 0.9108
#
# Epoch 25/39
# ----------
# train Loss: 0.4402 Acc: 0.8586
# val Loss: 0.2461 Acc: 0.9269
#
# Epoch 26/39
# ----------
# train Loss: 0.4992 Acc: 0.8267
# val Loss: 0.2769 Acc: 0.9021
#
# Epoch 27/39
# ----------
# train Loss: 0.4984 Acc: 0.8315
# val Loss: 0.2714 Acc: 0.9009
#
# Epoch 28/39
# ----------
# train Loss: 0.4362 Acc: 0.8511
# val Loss: 0.3173 Acc: 0.8835
#
# Epoch 29/39
# ----------
# train Loss: 0.4528 Acc: 0.8511
# val Loss: 0.2813 Acc: 0.8885
#
# Epoch 30/39
# ----------
# train Loss: 0.4386 Acc: 0.8495
# val Loss: 0.2522 Acc: 0.9157
#
# Epoch 31/39
# ----------
# train Loss: 0.4348 Acc: 0.8522
# val Loss: 0.3052 Acc: 0.8934
#
# Epoch 32/39
# ----------
# train Loss: 0.4395 Acc: 0.8506
# val Loss: 0.4602 Acc: 0.8451
#
# Epoch 33/39
# ----------
# train Loss: 0.4731 Acc: 0.8262
# val Loss: 0.3316 Acc: 0.8922
#
# Epoch 34/39
# ----------
# train Loss: 0.4265 Acc: 0.8602
# val Loss: 0.2927 Acc: 0.9033
#
# Epoch 35/39
# ----------
# train Loss: 0.4052 Acc: 0.8655
# val Loss: 0.3623 Acc: 0.8686
#
# Epoch 36/39
# ----------
# train Loss: 0.3977 Acc: 0.8623
# val Loss: 0.2364 Acc: 0.9232
#
# Epoch 37/39
# ----------
# train Loss: 0.4163 Acc: 0.8618
# val Loss: 0.2469 Acc: 0.9108
#
# Epoch 38/39
# ----------
# train Loss: 0.4242 Acc: 0.8602
# val Loss: 0.2246 Acc: 0.9195
#
# Epoch 39/39
# ----------
# train Loss: 0.3911 Acc: 0.8655
# val Loss: 0.2710 Acc: 0.9083
#
# Training complete in 8m 45s
# Best val Acc: 0.926890
# Epoch 0/39
# ----------
# train Loss: 1.1795 Acc: 0.6103
# val Loss: 0.5652 Acc: 0.8178
#
# Epoch 1/39
# ----------
# train Loss: 0.7001 Acc: 0.7608
# val Loss: 0.4365 Acc: 0.8439
#
# Epoch 2/39
# ----------
# train Loss: 0.6199 Acc: 0.7900
# val Loss: 0.3512 Acc: 0.8848
#
# Epoch 3/39
# ----------
# train Loss: 0.5800 Acc: 0.8054
# val Loss: 0.3266 Acc: 0.8897
#
# Epoch 4/39
# ----------
# train Loss: 0.5669 Acc: 0.8038
# val Loss: 0.2870 Acc: 0.8959
#
# Epoch 5/39
# ----------
# train Loss: 0.5181 Acc: 0.8272
# val Loss: 0.2569 Acc: 0.9195
#
# Epoch 6/39
# ----------
# train Loss: 0.5414 Acc: 0.8150
# val Loss: 0.2588 Acc: 0.8934
#
# Epoch 7/39
# ----------
# train Loss: 0.5332 Acc: 0.8060
# val Loss: 0.2833 Acc: 0.8996
#
# Epoch 8/39
# ----------
# train Loss: 0.5158 Acc: 0.8230
# val Loss: 0.2748 Acc: 0.8934
#
# Epoch 9/39
# ----------
# train Loss: 0.5253 Acc: 0.8187
# val Loss: 0.2414 Acc: 0.9083
#
# Epoch 10/39
# ----------
# train Loss: 0.5013 Acc: 0.8251
# val Loss: 0.2848 Acc: 0.9021
#
# Epoch 11/39
# ----------
# train Loss: 0.5139 Acc: 0.8208
# val Loss: 0.2341 Acc: 0.9071
#
# Epoch 12/39
# ----------
# train Loss: 0.5084 Acc: 0.8240
# val Loss: 0.2395 Acc: 0.9108
#
# Epoch 13/39
# ----------
# train Loss: 0.4878 Acc: 0.8235
# val Loss: 0.2780 Acc: 0.8959
#
# Epoch 14/39
# ----------
# train Loss: 0.4689 Acc: 0.8341
# val Loss: 0.2581 Acc: 0.9046
#
# Epoch 15/39
# ----------
# train Loss: 0.5003 Acc: 0.8293
# val Loss: 0.2375 Acc: 0.9145
#
# Epoch 16/39
# ----------
# train Loss: 0.4714 Acc: 0.8309
# val Loss: 0.3469 Acc: 0.8736
#
# Epoch 17/39
# ----------
# train Loss: 0.4686 Acc: 0.8325
# val Loss: 0.2720 Acc: 0.8947
#
# Epoch 18/39
# ----------
# train Loss: 0.4560 Acc: 0.8464
# val Loss: 0.2527 Acc: 0.9046
#
# Epoch 19/39
# ----------
# train Loss: 0.4568 Acc: 0.8336
# val Loss: 0.2613 Acc: 0.9021
#
# Epoch 20/39
# ----------
# train Loss: 0.4333 Acc: 0.8527
# val Loss: 0.2422 Acc: 0.9095
#
# Epoch 21/39
# ----------
# train Loss: 0.4768 Acc: 0.8341
# val Loss: 0.2878 Acc: 0.8860
#
# Epoch 22/39
# ----------
# train Loss: 0.4913 Acc: 0.8262
# val Loss: 0.3207 Acc: 0.8798
#
# Epoch 23/39
# ----------
# train Loss: 0.5002 Acc: 0.8203
# val Loss: 0.2914 Acc: 0.8872
#
# Epoch 24/39
# ----------
# train Loss: 0.4733 Acc: 0.8363
# val Loss: 0.2391 Acc: 0.9133
#
# Epoch 25/39
# ----------
# train Loss: 0.4535 Acc: 0.8400
# val Loss: 0.2516 Acc: 0.9133
#
# Epoch 26/39
# ----------
# train Loss: 0.4720 Acc: 0.8426
# val Loss: 0.2262 Acc: 0.9244
#
# Epoch 27/39
# ----------
# train Loss: 0.4538 Acc: 0.8363
# val Loss: 0.2604 Acc: 0.9133
#
# Epoch 28/39
# ----------
# train Loss: 0.4329 Acc: 0.8421
# val Loss: 0.2482 Acc: 0.9133
#
# Epoch 29/39
# ----------
# train Loss: 0.4611 Acc: 0.8464
# val Loss: 0.2421 Acc: 0.9071
#
# Epoch 30/39
# ----------
# train Loss: 0.4521 Acc: 0.8458
# val Loss: 0.2376 Acc: 0.9120
#
# Epoch 31/39
# ----------
# train Loss: 0.4467 Acc: 0.8394
# val Loss: 0.2505 Acc: 0.9145
#
# Epoch 32/39
# ----------
# train Loss: 0.4719 Acc: 0.8304
# val Loss: 0.2425 Acc: 0.9083
#
# Epoch 33/39
# ----------
# train Loss: 0.4718 Acc: 0.8426
# val Loss: 0.2375 Acc: 0.9120
#
# Epoch 34/39
# ----------
# train Loss: 0.4692 Acc: 0.8389
# val Loss: 0.2647 Acc: 0.9083
#
# Epoch 35/39
# ----------
# train Loss: 0.4541 Acc: 0.8442
# val Loss: 0.2385 Acc: 0.9120
#
# Epoch 36/39
# ----------
# train Loss: 0.4328 Acc: 0.8506
# val Loss: 0.2588 Acc: 0.9009
#
# Epoch 37/39
# ----------
# train Loss: 0.4534 Acc: 0.8458
# val Loss: 0.2198 Acc: 0.9257
#
# Epoch 38/39
# ----------
# train Loss: 0.4523 Acc: 0.8394
# val Loss: 0.3063 Acc: 0.8959
#
# Epoch 39/39
# ----------
# train Loss: 0.4716 Acc: 0.8389
# val Loss: 0.2352 Acc: 0.9182
#
# Training complete in 6m 39s
# Best val Acc: 0.925651

# %%
# YOUR CODE HERE contd

# plot the losses and accuracies of all models
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 6))

ax1.plot(all_loss_hist[0]["train"], label="from scratch")
ax1.plot(all_loss_hist[2]["train"], label="feature extraction")
ax1.plot(all_loss_hist[1]["train"], label="fine-tuning")
ax1.set_title("training loss")
ax1.set_xlabel("batch")
ax1.legend()

ax2.plot(all_loss_hist[0]["val"], label="from scratch")
ax2.plot(all_loss_hist[2]["val"], label="feature extraction")
ax2.plot(all_loss_hist[1]["val"], label="fine-tuning")
ax2.set_title("val loss")
ax2.set_xlabel("batch")
ax2.legend()

ax3.plot(all_acc_hist[0]["train"],label="from scratch")
ax3.plot(all_acc_hist[2]["train"],label="feature extraction")
ax3.plot(all_acc_hist[1]["train"],label="fine-tuning")
ax3.set_title("training accuracy")
ax3.set_xlabel("epoch")
ax3.legend()

ax4.plot(all_acc_hist[0]["val"],label="from scratch")
ax4.plot(all_acc_hist[2]["val"],label="feature extraction")
ax4.plot(all_acc_hist[1]["val"],label="fine-tuning")
ax4.set_title("val accuracy")
ax4.set_xlabel("epoch")
ax4.legend()

plt.tight_layout()

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 8**: Visualize some of the images along with the classification results of your best model.
#
# *Hints: (1) The images that the dataloader gives you are already normalised, you need to "de-normalise" them if you want to see the true colours. (2) The order of dimensions of PyTorch is C, H, W, if you want to plot images you need your arrays ordered as H, W, C.*
#
# </span>

# %%
# YOUR CODE HERE

with torch.no_grad():

    data, target = next(iter(dataloaders_dict["val"]))
    data, target = data.to(device), target.to(device)

    output = best_model(data)
    predictions = np.argmax(output.cpu().numpy(), axis=1).tolist()
    true = target.cpu().numpy().tolist()

    plt.figure(figsize=(16, 6))

    print("Correctly predicted: {}%".format(100*sum(p == t for p, t in zip(predictions, true))/len(predictions)) )

    for i in range(8):
        plt.subplot(2, 4, i + 1)

        image = data[i,...].cpu().clone().detach() # Create a copy of the tensor in the CPU
        image = image.permute(1, 2, 0) # The original tensor is formatted as Channels, Height, Width - move channels to the end
        image = image.numpy()

        # Undo the normalisation we applied before
        image = image * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])
        image = image.clip(0, 1)

        plt.imshow(image)

        plt.axis('off')
        plt.title('Predicted as {}\n True label is {}'.format(predictions[i], true[i], ))

    plt.tight_layout()
    plt.show()
# Out:
# Correctly predicted: 87.5%
